# %%
import sys
import nltk
import math
import pandas as pd
import numpy as np
from nltk.stem import PorterStemmer
ps = PorterStemmer()
word_list = ['is', 'am', 'are', 'was', 'were']
np.set_printoptions(threshold=sys.maxsize)

#stopwords from txt
my_file = open("stopwords.txt", "r")
stopwords = my_file.read()
stopwords = [stopwords.translate({ ord(c): None for c in '" ' }).split(",") ][0]#delete punctuation

# %%
def tokenize(data):
    data = [i.strip() for i in data.split(' ')]
    text = [i.lower() for i in data]
    text = [i.translate({ ord(c): None for c in '"1234567890' }) for i in text] #delete punctuation
    text = [i.translate({ ord(c): None for c in "#$%&'()*+,-./:;!<=>?@[\]^_`{|~} " }) for i in text] #delete punctuation
    text = [ps.stem(i) for i in text] #porter's algo
    text = ['be' if idx in word_list else idx for idx in text] #lemmatization
    text = [i for i in text if i not in stopwords] #stopwords delete
    text = list(filter(None, text)) #去除空字元
    return text

# %%
import requests
file_url = 'https://ceiba.ntu.edu.tw/course/88ca22/content/training.txt'
response = requests.get(file_url)
if (response.status_code):
    data = response.text
    #print(data) #original text
    classDict = [['keep zero empty']]
    for a in data.split('\n'):
        tmp = []
        a = a.strip()
        head = a.split(' ')[0]
        tmp = a.split(' ')[1:]
        classDict.append(tmp)
#classDict

# %%
#建一個總體的字典
def buildDict(text): #只算有無出現, 弄成list
    for word in text:
        if word not in Allwords:
            Allwords.append(word)

Allwords = []
for i in range(1,14):
    for docid in classDict[i]:
        with open(f'./data/{docid}.txt') as f:
            data=f.read()
            text = tokenize(data) 
            buildDict(text)
Allwords_dict = sorted(Allwords) #照字母排
AllwordSize = len(Allwords_dict) #總term數
AllwordSize
# Out:
# 5170

# %%
eachCategorycnt_dict = [['keep zero empty']] #方便計算從1開始到13
wcount_dict = [['keep zero empty']] #計算每類別中'總字數'有多少
for i in range(1,14):
    dict_from_list = {k: 0 for k in Allwords_dict}
    wcount = 0
    for docid in classDict[i]:
        with open(f'./data/{docid}.txt') as f:
            data=f.read()
            text = tokenize(data) 
            for word in text:
                dict_from_list[word] += 1
                wcount+=1
    eachCategorycnt_dict.append(dict_from_list)
    wcount_dict.append(wcount)
#eachCategorycnt_dict

# %%
#算出每個字在每個類別中出現的比率分數
import copy

params_dict = copy.deepcopy(eachCategorycnt_dict)
for category in range(1,14):
    for k in params_dict[category]:
        params_dict[category][k] = (params_dict[category][k]+1) / (wcount_dict[category]+AllwordSize)
#params_dict[13]
# Out:
# {'aaron': 9.989012086704625e-05,
#  'abandon': 9.989012086704625e-05,
#  'abc': 9.989012086704625e-05,
#  'abccom': 9.989012086704625e-05,
#  'abdallah': 9.989012086704625e-05,
#  'abhorr': 9.989012086704625e-05,
#  'abid': 9.989012086704625e-05,
#  'abidjan': 9.989012086704625e-05,
#  'abil': 9.989012086704625e-05,
#  'abl': 0.00029967036260113877,
#  'aboard': 9.989012086704625e-05,
#  'abou': 9.989012086704625e-05,
#  'abov': 9.989012086704625e-05,
#  'abroad': 0.0004994506043352313,
#  'absenc': 9.989012086704625e-05,
#  'absente': 9.989012086704625e-05,
#  'absolut': 9.989012086704625e-05,
#  'abund': 9.989012086704625e-05,
#  'abus': 9.989012086704625e-05,
#  'academi': 9.989012086704625e-05,
#  'acced': 0.0001997802417340925,
#  'accept': 9.989012086704625e-05,
#  'access': 9.989012086704625e-05,
#  'accid': 9.989012086704625e-05,
#  'accident': 9.989012086704625e-05,
#  'accompani': 0.0005993407252022775,
#  'accomplish': 0.0001997802417340925,
#  'accord': 0.00029967036260113877,
#  'account': 0.0012985715712716013,
#  'accur': 0.0001997802417340925,
#  'accus': 9.989012086704625e-05,
#  'ace': 9.989012086704625e-05,
#  'achiev': 0.0004994506043352313,
#  'acknowledg': 0.0001997802417340925,
#  'acquit': 9.989012086704625e-05,
#  'acquitt': 9.989012086704625e-05,
#  'acrobat': 9.989012086704625e-05,
#  'action': 0.00079912096693637,
#  'activ': 9.989012086704625e-05,
#  'activist': 9.989012086704625e-05,
#  'actual': 0.0001997802417340925,
#  'add': 9.989012086704625e-05,
#  'addit': 0.00029967036260113877,
#  'address': 0.0004994506043352313,
#  'aden': 9.989012086704625e-05,
#  'adequ': 9.989012086704625e-05,
#  'adjam': 9.989012086704625e-05,
#  'adjourn': 9.989012086704625e-05,
#  'admen': 9.989012086704625e-05,
#  'administ': 9.989012086704625e-05,
#  'administr': 0.0006992308460693238,
#  'admir': 9.989012086704625e-05,
#  'admiringli': 0.0001997802417340925,
#  'admit': 9.989012086704625e-05,
#  'ado': 9.989012086704625e-05,
#  'adopt': 9.989012086704625e-05,
#  'adorn': 9.989012086704625e-05,
#  'adra': 9.989012086704625e-05,
#  'adult': 9.989012086704625e-05,
#  'advanc': 9.989012086704625e-05,
#  'advani': 9.989012086704625e-05,
#  'adventist': 9.989012086704625e-05,
#  'advertis': 0.0001997802417340925,
#  'advic': 0.0001997802417340925,
#  'advis': 0.0004994506043352313,
#  'advisor': 9.989012086704625e-05,
#  'aegi': 9.989012086704625e-05,
#  'aerial': 9.989012086704625e-05,
#  'affair': 0.000399560483468185,
#  'affect': 9.989012086704625e-05,
#  'affirm': 9.989012086704625e-05,
#  'afghanistan': 9.989012086704625e-05,
#  'afraid': 0.00029967036260113877,
#  'africa': 9.989012086704625e-05,
#  'african': 9.989012086704625e-05,
#  'afternoon': 9.989012086704625e-05,
#  'aftershock': 9.989012086704625e-05,
#  'afterward': 9.989012086704625e-05,
#  'agassi': 9.989012086704625e-05,
#  'age': 0.000399560483468185,
#  'agenc': 0.00029967036260113877,
#  'agenda': 0.00029967036260113877,
#  'agent': 0.00029967036260113877,
#  'aggrav': 9.989012086704625e-05,
#  'aggress': 9.989012086704625e-05,
#  'ago': 0.0012985715712716013,
#  'agon': 0.00029967036260113877,
#  'agre': 0.00029967036260113877,
#  'agreement': 0.001198681450404555,
#  'agricultur': 9.989012086704625e-05,
#  'ahead': 9.989012086704625e-05,
#  'ahm': 9.989012086704625e-05,
#  'ahmadabad': 9.989012086704625e-05,
#  'ahmedabad': 9.989012086704625e-05,
#  'aid': 0.0004994506043352313,
#  'ail': 9.989012086704625e-05,
#  'aim': 0.0001997802417340925,
#  'air': 0.00079912096693637,
#  'aircraft': 0.00029967036260113877,
#  'airlift': 9.989012086704625e-05,
#  'airlin': 0.0001997802417340925,
#  'airmen': 9.989012086704625e-05,
#  'airplan': 9.989012086704625e-05,
#  'airport': 0.00029967036260113877,
#  'aisl': 9.989012086704625e-05,
#  'akin': 0.0001997802417340925,
#  'akishio': 9.989012086704625e-05,
#  'ala': 9.989012086704625e-05,
#  'alarm': 9.989012086704625e-05,
#  'alaskan': 9.989012086704625e-05,
#  'alassan': 9.989012086704625e-05,
#  'albani': 9.989012086704625e-05,
#  'albanian': 9.989012086704625e-05,
#  'albeit': 9.989012086704625e-05,
#  'albert': 9.989012086704625e-05,
#  'alberto': 9.989012086704625e-05,
#  'albright': 0.00029967036260113877,
#  'alcohol': 9.989012086704625e-05,
#  'alejandro': 9.989012086704625e-05,
#  'aleksa': 9.989012086704625e-05,
#  'alert': 9.989012086704625e-05,
#  'alex': 9.989012086704625e-05,
#  'alexand': 9.989012086704625e-05,
#  'alexandria': 9.989012086704625e-05,
#  'ali': 9.989012086704625e-05,
#  'alibi': 9.989012086704625e-05,
#  'align': 0.0001997802417340925,
#  'alik': 9.989012086704625e-05,
#  'aliv': 0.00029967036260113877,
#  'allahabad': 9.989012086704625e-05,
#  'alleg': 9.989012086704625e-05,
#  'allegedli': 9.989012086704625e-05,
#  'allen': 9.989012086704625e-05,
#  'alli': 0.000399560483468185,
#  'alnaderi': 9.989012086704625e-05,
#  'alon': 9.989012086704625e-05,
#  'alongsid': 9.989012086704625e-05,
#  'alpha': 9.989012086704625e-05,
#  'alphabet': 9.989012086704625e-05,
#  'alreadi': 0.0001997802417340925,
#  'alter': 9.989012086704625e-05,
#  'altern': 9.989012086704625e-05,
#  'altitud': 9.989012086704625e-05,
#  'alun': 9.989012086704625e-05,
#  'alway': 0.0001997802417340925,
#  'amanda': 9.989012086704625e-05,
#  'amass': 9.989012086704625e-05,
#  'amateur': 9.989012086704625e-05,
#  'amaz': 9.989012086704625e-05,
#  'ambassador': 0.000399560483468185,
#  'ambival': 0.0001997802417340925,
#  'ambul': 9.989012086704625e-05,
#  'amend': 9.989012086704625e-05,
#  'amerasian': 0.0001997802417340925,
#  'america': 0.0014983518130056938,
#  'american': 0.004395165318150035,
#  'amid': 0.00029967036260113877,
#  'ammo': 9.989012086704625e-05,
#  'ammunit': 9.989012086704625e-05,
#  'amp': 9.989012086704625e-05,
#  'ampl': 9.989012086704625e-05,
#  'ana': 9.989012086704625e-05,
#  'analyst': 0.000399560483468185,
#  'analyz': 9.989012086704625e-05,
#  'anca': 9.989012086704625e-05,
#  'ancestr': 9.989012086704625e-05,
#  'andr': 9.989012086704625e-05,
#  'andrea': 9.989012086704625e-05,
#  'andrew': 9.989012086704625e-05,
#  'angel': 0.0001997802417340925,
#  'anger': 9.989012086704625e-05,
#  'angl': 9.989012086704625e-05,
#  'angri': 9.989012086704625e-05,
#  'anguish': 9.989012086704625e-05,
#  'ani': 0.0005993407252022775,
#  'animos': 0.0001997802417340925,
#  'ank': 9.989012086704625e-05,
#  'ankl': 9.989012086704625e-05,
#  'ann': 0.00029967036260113877,
#  'anna': 9.989012086704625e-05,
#  'annabel': 9.989012086704625e-05,
#  'annacon': 9.989012086704625e-05,
#  'annan': 9.989012086704625e-05,
#  'anniversari': 9.989012086704625e-05,
#  'announc': 0.0005993407252022775,
#  'annual': 0.0004994506043352313,
#  'anonym': 9.989012086704625e-05,
#  'anoth': 0.00029967036260113877,
#  'answer': 9.989012086704625e-05,
#  'antasiaovich': 9.989012086704625e-05,
#  'antenna': 9.989012086704625e-05,
#  'anthoni': 9.989012086704625e-05,
#  'anthropologist': 0.0004994506043352313,
#  'antibiot': 9.989012086704625e-05,
#  'anticip': 9.989012086704625e-05,
#  'antifbi': 9.989012086704625e-05,
#  'antimilosev': 9.989012086704625e-05,
#  'antiterror': 9.989012086704625e-05,
#  'antiu': 9.989012086704625e-05,
#  'antiwar': 0.000399560483468185,
#  'antonia': 9.989012086704625e-05,
#  'antonio': 9.989012086704625e-05,
#  'anwar': 9.989012086704625e-05,
#  'anxieti': 0.0001997802417340925,
#  'anxiou': 0.0001997802417340925,
#  'anxious': 9.989012086704625e-05,
#  'anybodi': 9.989012086704625e-05,
#  'anymor': 9.989012086704625e-05,
#  'anyon': 0.0004994506043352313,
#  'anyth': 9.989012086704625e-05,
#  'anytim': 9.989012086704625e-05,
#  'anywher': 0.0001997802417340925,
#  'apec': 0.0005993407252022775,
#  'apolog': 0.0005993407252022775,
#  'appar': 9.989012086704625e-05,
#  'apparatu': 9.989012086704625e-05,
#  'appeal': 9.989012086704625e-05,
#  'appli': 9.989012086704625e-05,
#  'applic': 0.0001997802417340925,
#  'appoint': 9.989012086704625e-05,
#  'approach': 9.989012086704625e-05,
#  'approv': 0.00029967036260113877,
#  'april': 9.989012086704625e-05,
#  'arabia': 9.989012086704625e-05,
#  'arabian': 9.989012086704625e-05,
#  'arafat': 9.989012086704625e-05,
#  'arazi': 9.989012086704625e-05,
#  'arbitrari': 0.0001997802417340925,
#  'archaeolog': 0.00029967036260113877,
#  'archi': 9.989012086704625e-05,
#  'archibald': 9.989012086704625e-05,
#  'architect': 9.989012086704625e-05,
#  'arctic': 9.989012086704625e-05,
#  'area': 9.989012086704625e-05,
#  'arena': 9.989012086704625e-05,
#  'argentin': 9.989012086704625e-05,
#  'argu': 0.00029967036260113877,
#  'argument': 9.989012086704625e-05,
#  'arid': 9.989012086704625e-05,
#  'arif': 9.989012086704625e-05,
#  'aritomi': 9.989012086704625e-05,
#  'arizona': 9.989012086704625e-05,
#  'arkansa': 9.989012086704625e-05,
#  'arkin': 9.989012086704625e-05,
#  'arlington': 9.989012086704625e-05,
#  'arm': 0.00029967036260113877,
#  'armament': 9.989012086704625e-05,
#  'armi': 0.00029967036260113877,
#  'armor': 9.989012086704625e-05,
#  'armori': 9.989012086704625e-05,
#  'arrang': 9.989012086704625e-05,
#  'arrest': 9.989012086704625e-05,
#  'arriv': 0.0006992308460693238,
#  'arsen': 9.989012086704625e-05,
#  'arseni': 9.989012086704625e-05,
#  'arthriti': 9.989012086704625e-05,
#  'artifact': 0.0001997802417340925,
#  'artifici': 9.989012086704625e-05,
#  'artist': 9.989012086704625e-05,
#  'arturo': 9.989012086704625e-05,
#  'asean': 0.0001997802417340925,
#  'ashcroft': 9.989012086704625e-05,
#  'ashkroft': 9.989012086704625e-05,
#  'ashor': 9.989012086704625e-05,
#  'ashtray': 9.989012086704625e-05,
#  'asia': 0.0016981320547397863,
#  'asian': 0.000399560483468185,
#  'asiapacif': 0.00079912096693637,
#  'asid': 0.0001997802417340925,
#  'assail': 9.989012086704625e-05,
#  'assam': 9.989012086704625e-05,
#  'assassin': 9.989012086704625e-05,
#  'assault': 9.989012086704625e-05,
#  'assembl': 9.989012086704625e-05,
#  'assess': 9.989012086704625e-05,
#  'assign': 9.989012086704625e-05,
#  'assist': 9.989012086704625e-05,
#  'associ': 0.00029967036260113877,
#  'assum': 9.989012086704625e-05,
#  'assur': 0.0005993407252022775,
#  'astakhov': 9.989012086704625e-05,
#  'astonish': 9.989012086704625e-05,
#  'astronom': 9.989012086704625e-05,
#  'asylum': 0.0001997802417340925,
#  'atal': 9.989012086704625e-05,
#  'ath': 9.989012086704625e-05,
#  'atlanta': 9.989012086704625e-05,
#  'atom': 9.989012086704625e-05,
#  'atop': 9.989012086704625e-05,
#  'atp': 9.989012086704625e-05,
#  'attach': 9.989012086704625e-05,
#  'attack': 0.0001997802417340925,
#  'attempt': 0.0001997802417340925,
#  'attend': 0.000399560483468185,
#  'attent': 9.989012086704625e-05,
#  'attitud': 0.0001997802417340925,
#  'attorney': 9.989012086704625e-05,
#  'attract': 0.0001997802417340925,
#  'attribut': 9.989012086704625e-05,
#  'aubrey': 9.989012086704625e-05,
#  'aubri': 9.989012086704625e-05,
#  'audienc': 9.989012086704625e-05,
#  'aug': 9.989012086704625e-05,
#  'august': 0.0004994506043352313,
#  'aunt': 9.989012086704625e-05,
#  'aura': 9.989012086704625e-05,
#  'aussi': 9.989012086704625e-05,
#  'auster': 0.0001997802417340925,
#  'austin': 9.989012086704625e-05,
#  'australia': 0.0001997802417340925,
#  'australian': 9.989012086704625e-05,
#  'author': 0.00079912096693637,
#  'authoritarian': 9.989012086704625e-05,
#  'autocrat': 9.989012086704625e-05,
#  'automat': 9.989012086704625e-05,
#  'automobil': 9.989012086704625e-05,
#  'autonomi': 9.989012086704625e-05,
#  'autopsi': 9.989012086704625e-05,
#  'avail': 9.989012086704625e-05,
#  'avenu': 9.989012086704625e-05,
#  'averag': 0.00029967036260113877,
#  'aviat': 9.989012086704625e-05,
#  'avoid': 0.000399560483468185,
#  'await': 0.00029967036260113877,
#  'awar': 9.989012086704625e-05,
#  'award': 9.989012086704625e-05,
#  'awe': 9.989012086704625e-05,
#  'awkward': 9.989012086704625e-05,
#  'ayr': 9.989012086704625e-05,
#  'babi': 9.989012086704625e-05,
#  'babkin': 9.989012086704625e-05,
#  'backandforth': 9.989012086704625e-05,
#  'backdrop': 0.0001997802417340925,
#  'backhand': 9.989012086704625e-05,
#  'backup': 9.989012086704625e-05,
#  'bad': 9.989012086704625e-05,
#  'badg': 9.989012086704625e-05,
#  'badli': 9.989012086704625e-05,
#  'bag': 0.00029967036260113877,
#  'bahgbo': 9.989012086704625e-05,
#  'bahrain': 9.989012086704625e-05,
#  'baijubahi': 9.989012086704625e-05,
#  'bailey': 9.989012086704625e-05,
#  'balanc': 0.00029967036260113877,
#  'balintkurti': 9.989012086704625e-05,
#  'balkan': 9.989012086704625e-05,
#  'ball': 9.989012086704625e-05,
#  'ballist': 9.989012086704625e-05,
#  'ballot': 9.989012086704625e-05,
#  'balsamo': 9.989012086704625e-05,
#  'baltimor': 9.989012086704625e-05,
#  'ban': 9.989012086704625e-05,
#  'band': 9.989012086704625e-05,
#  'bandanna': 9.989012086704625e-05,
#  'bandit': 9.989012086704625e-05,
#  'bang': 9.989012086704625e-05,
#  'bangladesh': 9.989012086704625e-05,
#  'bank': 9.989012086704625e-05,
#  'banner': 9.989012086704625e-05,
#  'bar': 0.00029967036260113877,
#  'barak': 9.989012086704625e-05,
#  'barb': 9.989012086704625e-05,
#  'barbara': 9.989012086704625e-05,
#  'bare': 0.0001997802417340925,
#  'barent': 9.989012086704625e-05,
#  'bark': 9.989012086704625e-05,
#  'barkina': 9.989012086704625e-05,
#  'barkolla': 9.989012086704625e-05,
#  'barkova': 9.989012086704625e-05,
#  'barna': 9.989012086704625e-05,
#  'barrack': 9.989012086704625e-05,
#  'barricad': 9.989012086704625e-05,
#  'barrier': 0.0001997802417340925,
#  'bartlett': 9.989012086704625e-05,
#  'base': 9.989012086704625e-05,
#  'baselin': 9.989012086704625e-05,
#  'basi': 0.0001997802417340925,
#  'basic': 0.0001997802417340925,
#  'basket': 9.989012086704625e-05,
#  'batch': 9.989012086704625e-05,
#  'bathroom': 9.989012086704625e-05,
#  'batten': 9.989012086704625e-05,
#  'batter': 9.989012086704625e-05,
#  'battl': 0.0001997802417340925,
#  'battlefield': 0.0001997802417340925,
#  'bauman': 9.989012086704625e-05,
#  'bavaria': 9.989012086704625e-05,
#  'bbc': 9.989012086704625e-05,
#  'beach': 0.000399560483468185,
#  'bear': 0.000399560483468185,
#  'beard': 9.989012086704625e-05,
#  'beat': 0.0001997802417340925,
#  'beaten': 9.989012086704625e-05,
#  'beauti': 9.989012086704625e-05,
#  'becam': 0.00029967036260113877,
#  'becaus': 0.0009989012086704626,
#  'becom': 0.0004994506043352313,
#  'bed': 9.989012086704625e-05,
#  'bedi': 9.989012086704625e-05,
#  'befor': 0.00079912096693637,
#  'began': 0.0006992308460693238,
#  'begun': 9.989012086704625e-05,
#  'behari': 9.989012086704625e-05,
#  'behavior': 9.989012086704625e-05,
#  'bekki': 9.989012086704625e-05,
#  'belch': 9.989012086704625e-05,
#  'belgrad': 9.989012086704625e-05,
#  'belief': 0.0001997802417340925,
#  'believ': 0.0010987913295375088,
#  'bell': 9.989012086704625e-05,
#  'belov': 9.989012086704625e-05,
#  'belt': 9.989012086704625e-05,
#  'bema': 9.989012086704625e-05,
#  'beneath': 9.989012086704625e-05,
#  'benefactor': 9.989012086704625e-05,
#  'benefit': 0.0005993407252022775,
#  'beretta': 9.989012086704625e-05,
#  'bergen': 9.989012086704625e-05,
#  'berger': 0.0010987913295375088,
#  'berlin': 9.989012086704625e-05,
#  'berth': 9.989012086704625e-05,
#  'besid': 0.0001997802417340925,
#  'besieg': 9.989012086704625e-05,
#  'bestkept': 9.989012086704625e-05,
#  'bestknown': 9.989012086704625e-05,
#  'bet': 0.0001997802417340925,
#  'beta': 9.989012086704625e-05,
#  'betray': 9.989012086704625e-05,
#  'bhaba': 9.989012086704625e-05,
#  'bhagat': 9.989012086704625e-05,
#  'bhat': 9.989012086704625e-05,
#  'bhuj': 9.989012086704625e-05,
#  'bias': 9.989012086704625e-05,
#  'bicycl': 9.989012086704625e-05,
#  'bid': 9.989012086704625e-05,
#  'big': 9.989012086704625e-05,
#  'biggest': 9.989012086704625e-05,
#  'bihari': 9.989012086704625e-05,
#  'bilater': 0.0004994506043352313,
#  'billboard': 0.0001997802417340925,
#  'billion': 0.0001997802417340925,
#  'biltera': 9.989012086704625e-05,
#  'bin': 9.989012086704625e-05,
#  'bind': 0.0001997802417340925,
#  'bindra': 9.989012086704625e-05,
#  'bird': 9.989012086704625e-05,
#  'birger': 9.989012086704625e-05,
#  'birthday': 9.989012086704625e-05,
#  'bit': 9.989012086704625e-05,
#  'bitter': 9.989012086704625e-05,
#  'bitterli': 0.0001997802417340925,
#  'black': 9.989012086704625e-05,
#  'blacken': 9.989012086704625e-05,
#  'blackmail': 9.989012086704625e-05,
#  'blackout': 9.989012086704625e-05,
#  'blair': 9.989012086704625e-05,
#  'blakemor': 9.989012086704625e-05,
#  'blame': 9.989012086704625e-05,
#  'blanco': 9.989012086704625e-05,
#  'blanket': 9.989012086704625e-05,
#  'blare': 9.989012086704625e-05,
#  'blast': 9.989012086704625e-05,
#  'blatant': 9.989012086704625e-05,
#  'bleacher': 9.989012086704625e-05,
#  'bled': 9.989012086704625e-05,
#  'bleed': 9.989012086704625e-05,
#  'blemish': 9.989012086704625e-05,
#  'blew': 9.989012086704625e-05,
#  'blink': 9.989012086704625e-05,
#  'bloc': 9.989012086704625e-05,
#  'block': 9.989012086704625e-05,
#  'blockad': 9.989012086704625e-05,
#  'blood': 9.989012086704625e-05,
#  'bloodchil': 9.989012086704625e-05,
#  'bloodsh': 9.989012086704625e-05,
#  'blow': 9.989012086704625e-05,
#  'blue': 9.989012086704625e-05,
#  'blueprint': 9.989012086704625e-05,
#  'bluewat': 9.989012086704625e-05,
#  'bluf': 9.989012086704625e-05,
#  'blvd': 9.989012086704625e-05,
#  'bnai': 9.989012086704625e-05,
#  'board': 9.989012086704625e-05,
#  'boast': 9.989012086704625e-05,
#  'boat': 0.0001997802417340925,
#  'bob': 9.989012086704625e-05,
#  'bodi': 0.00029967036260113877,
#  'bodyguard': 9.989012086704625e-05,
#  'bodyhunt': 9.989012086704625e-05,
#  'bold': 9.989012086704625e-05,
#  'bolona': 9.989012086704625e-05,
#  'bomb': 0.000399560483468185,
#  'bombay': 9.989012086704625e-05,
#  'bomber': 9.989012086704625e-05,
#  'bombet': 9.989012086704625e-05,
#  'bombey': 9.989012086704625e-05,
#  'bond': 9.989012086704625e-05,
#  'bone': 0.0004994506043352313,
#  'bonfir': 9.989012086704625e-05,
#  'book': 0.0001997802417340925,
#  'boom': 9.989012086704625e-05,
#  'boost': 9.989012086704625e-05,
#  'boot': 9.989012086704625e-05,
#  'border': 9.989012086704625e-05,
#  'bore': 9.989012086704625e-05,
#  'born': 0.0001997802417340925,
#  'borneo': 0.0004994506043352313,
#  'bosnian': 9.989012086704625e-05,
#  'boston': 9.989012086704625e-05,
#  'bostoni': 9.989012086704625e-05,
#  'bother': 9.989012086704625e-05,
#  'boucher': 9.989012086704625e-05,
#  'boulevard': 9.989012086704625e-05,
#  'bounc': 9.989012086704625e-05,
#  'bound': 9.989012086704625e-05,
#  'bout': 9.989012086704625e-05,
#  'bow': 9.989012086704625e-05,
#  'bowen': 9.989012086704625e-05,
#  'bowl': 0.0001997802417340925,
#  'bowmen': 9.989012086704625e-05,
#  'box': 9.989012086704625e-05,
#  'boy': 9.989012086704625e-05,
#  'boycot': 9.989012086704625e-05,
#  'boycott': 9.989012086704625e-05,
#  'boyfriend': 9.989012086704625e-05,
#  'brace': 9.989012086704625e-05,
#  'bracket': 9.989012086704625e-05,
#  'brain': 0.0001997802417340925,
#  'branch': 9.989012086704625e-05,
#  'brandish': 9.989012086704625e-05,
#  'brash': 9.989012086704625e-05,
#  'brazil': 9.989012086704625e-05,
#  'brazilian': 9.989012086704625e-05,
#  'break': 9.989012086704625e-05,
#  'breaker': 9.989012086704625e-05,
#  'breakfast': 9.989012086704625e-05,
#  'breakout': 9.989012086704625e-05,
#  'breakthrough': 0.0001997802417340925,
#  'breakup': 9.989012086704625e-05,
#  'breast': 9.989012086704625e-05,
#  'breme': 9.989012086704625e-05,
#  'bribe': 9.989012086704625e-05,
#  'briberi': 9.989012086704625e-05,
#  'brick': 9.989012086704625e-05,
#  'bride': 0.0001997802417340925,
#  'bridg': 9.989012086704625e-05,
#  'brie': 9.989012086704625e-05,
#  'briefli': 9.989012086704625e-05,
#  'brig': 9.989012086704625e-05,
#  'bright': 0.0001997802417340925,
#  'brilliant': 9.989012086704625e-05,
#  'bring': 0.00029967036260113877,
#  'briskli': 9.989012086704625e-05,
#  'britain': 9.989012086704625e-05,
#  'brith': 9.989012086704625e-05,
#  'british': 9.989012086704625e-05,
#  'broadcast': 0.000399560483468185,
#  'broadli': 9.989012086704625e-05,
#  'broke': 9.989012086704625e-05,
#  'broken': 9.989012086704625e-05,
#  'broker': 9.989012086704625e-05,
#  'brother': 9.989012086704625e-05,
#  'brotherinlaw': 9.989012086704625e-05,
#  'brought': 0.0001997802417340925,
#  'brown': 9.989012086704625e-05,
#  'bruis': 9.989012086704625e-05,
#  'brunei': 0.00159824193387274,
#  'brunswick': 9.989012086704625e-05,
#  'brunt': 9.989012086704625e-05,
#  'brutal': 0.0001997802417340925,
#  'bryann': 9.989012086704625e-05,
#  'bucket': 0.00029967036260113877,
#  'bud': 9.989012086704625e-05,
#  'budget': 9.989012086704625e-05,
#  'budnev': 9.989012086704625e-05,
#  'build': 0.0001997802417340925,
#  'built': 0.00029967036260113877,
#  'bulki': 9.989012086704625e-05,
#  'bulldoz': 9.989012086704625e-05,
#  'bullet': 9.989012086704625e-05,
#  'bulletin': 9.989012086704625e-05,
#  'bulletproof': 9.989012086704625e-05,
#  'bulli': 9.989012086704625e-05,
#  'bunch': 0.0006992308460693238,
#  'buoy': 9.989012086704625e-05,
#  'burch': 9.989012086704625e-05,
#  'bureau': 9.989012086704625e-05,
#  'bureaucraci': 0.00029967036260113877,
#  'bureaucrat': 0.00029967036260113877,
#  'burglar': 9.989012086704625e-05,
#  'burglari': 9.989012086704625e-05,
#  'buri': 0.0001997802417340925,
#  'burk': 9.989012086704625e-05,
#  'burkina': 9.989012086704625e-05,
#  'burkl': 9.989012086704625e-05,
#  'burn': 9.989012086704625e-05,
#  'buse': 9.989012086704625e-05,
#  'bush': 0.0005993407252022775,
#  'busi': 0.0022974727799420637,
#  'businessman': 9.989012086704625e-05,
#  'businessmen': 9.989012086704625e-05,
#  'bust': 9.989012086704625e-05,
#  'butcher': 9.989012086704625e-05,
#  'buy': 9.989012086704625e-05,
#  'buzz': 9.989012086704625e-05,
#  'cabin': 9.989012086704625e-05,
#  'cabinet': 9.989012086704625e-05,
#  'cabl': 9.989012086704625e-05,
#  'cacak': 9.989012086704625e-05,
#  'cafe': 9.989012086704625e-05,
#  'cahokia': 9.989012086704625e-05,
#  'cake': 9.989012086704625e-05,
#  'calam': 9.989012086704625e-05,
#  'calamit': 9.989012086704625e-05,
#  'calcutta': 9.989012086704625e-05,
#  'calib': 9.989012086704625e-05,
#  'calif': 9.989012086704625e-05,
#  'california': 9.989012086704625e-05,
#  'caller': 9.989012086704625e-05,
#  'calloff': 9.989012086704625e-05,
#  'calm': 0.0001997802417340925,
#  'calvario': 9.989012086704625e-05,
#  'calvert': 9.989012086704625e-05,
#  'cambodia': 0.0006992308460693238,
#  'camera': 9.989012086704625e-05,
#  'camp': 0.0004994506043352313,
#  'campaign': 9.989012086704625e-05,
#  'campfir': 9.989012086704625e-05,
#  'campu': 9.989012086704625e-05,
#  'canada': 9.989012086704625e-05,
#  'canal': 9.989012086704625e-05,
#  'cancel': 0.00029967036260113877,
#  'cancer': 9.989012086704625e-05,
#  'candid': 0.00029967036260113877,
#  'candidaci': 9.989012086704625e-05,
#  'candl': 9.989012086704625e-05,
#  'cannaday': 9.989012086704625e-05,
#  'cap': 9.989012086704625e-05,
#  'capabl': 9.989012086704625e-05,
#  'capac': 9.989012086704625e-05,
#  'capit': 0.0005993407252022775,
#  'capitol': 9.989012086704625e-05,
#  'capriati': 9.989012086704625e-05,
#  'capsul': 9.989012086704625e-05,
#  'capt': 0.000399560483468185,
#  'captain': 9.989012086704625e-05,
#  'captiv': 0.00029967036260113877,
#  'captur': 0.0001997802417340925,
#  'car': 0.0001997802417340925,
#  'carat': 0.0001997802417340925,
#  'card': 9.989012086704625e-05,
#  'care': 0.000399560483468185,
#  'career': 9.989012086704625e-05,
#  'carefullypreserv': 0.0001997802417340925,
#  'carlo': 9.989012086704625e-05,
#  'carlton': 9.989012086704625e-05,
#  'carmen': 9.989012086704625e-05,
#  'carmodi': 9.989012086704625e-05,
#  'carnahan': 9.989012086704625e-05,
#  'carol': 9.989012086704625e-05,
#  'carolina': 9.989012086704625e-05,
#  'carpet': 0.0001997802417340925,
#  'carr': 9.989012086704625e-05,
#  'carri': 9.989012086704625e-05,
#  'carrier': 9.989012086704625e-05,
#  'carrot': 9.989012086704625e-05,
#  'carsiz': 9.989012086704625e-05,
#  'carv': 9.989012086704625e-05,
#  'carver': 9.989012086704625e-05,
#  'case': 0.001198681450404555,
#  'casetch': 9.989012086704625e-05,
#  'cash': 0.0001997802417340925,
#  'cashier': 9.989012086704625e-05,
#  'casket': 9.989012086704625e-05,
#  'cast': 9.989012086704625e-05,
#  'castro': 9.989012086704625e-05,
#  'casualti': 9.989012086704625e-05,
#  'catastroph': 9.989012086704625e-05,
#  'catch': 9.989012086704625e-05,
#  'catchup': 9.989012086704625e-05,
#  'catherin': 9.989012086704625e-05,
#  'cathol': 9.989012086704625e-05,
#  'cattl': 9.989012086704625e-05,
#  'caucasian': 0.00029967036260113877,
#  'caught': 0.0001997802417340925,
#  'caus': 9.989012086704625e-05,
#  'caution': 9.989012086704625e-05,
#  'cautiou': 0.000399560483468185,
#  'cautious': 9.989012086704625e-05,
#  'cayman': 9.989012086704625e-05,
#  'ceasefir': 9.989012086704625e-05,
#  'cede': 9.989012086704625e-05,
#  'celebr': 0.0001997802417340925,
#  'celest': 9.989012086704625e-05,
#  'cell': 9.989012086704625e-05,
#  'cellular': 9.989012086704625e-05,
#  'cement': 9.989012086704625e-05,
#  'cementreinforc': 9.989012086704625e-05,
#  'censor': 0.0001997802417340925,
#  'center': 0.00029967036260113877,
#  'central': 9.989012086704625e-05,
#  'centrist': 9.989012086704625e-05,
#  'centuri': 0.0004994506043352313,
#  'ceo': 9.989012086704625e-05,
#  'ceremoni': 0.00079912096693637,
#  'cerf': 9.989012086704625e-05,
#  'certainli': 9.989012086704625e-05,
#  'certif': 9.989012086704625e-05,
#  'cesar': 9.989012086704625e-05,
#  'cessna': 9.989012086704625e-05,
#  'cha': 0.0001997802417340925,
#  'chad': 9.989012086704625e-05,
#  'chair': 0.0001997802417340925,
#  'chairman': 9.989012086704625e-05,
#  'challeng': 0.000399560483468185,
#  'champion': 9.989012086704625e-05,
#  'championship': 9.989012086704625e-05,
#  'chanc': 9.989012086704625e-05,
#  'chancellor': 9.989012086704625e-05,
#  'chang': 0.000399560483468185,
#  'channel': 9.989012086704625e-05,
#  'chant': 9.989012086704625e-05,
#  'chao': 9.989012086704625e-05,
#  'chaotic': 9.989012086704625e-05,
#  'chap': 9.989012086704625e-05,
#  'chapel': 9.989012086704625e-05,
#  'chappaqua': 9.989012086704625e-05,
#  'chapter': 0.0005993407252022775,
#  'charact': 9.989012086704625e-05,
#  'charg': 0.0004994506043352313,
#  'charl': 0.0001997802417340925,
#  'charleston': 9.989012086704625e-05,
#  'chase': 9.989012086704625e-05,
#  'chasm': 9.989012086704625e-05,
#  'cheat': 9.989012086704625e-05,
#  'chebeck': 9.989012086704625e-05,
#  'chechnya': 9.989012086704625e-05,
#  'check': 9.989012086704625e-05,
#  'cheer': 9.989012086704625e-05,
#  'chef': 0.0001997802417340925,
#  'chelsea': 0.0005993407252022775,
#  'cheney': 9.989012086704625e-05,
#  'cheri': 9.989012086704625e-05,
#  'chetsov': 9.989012086704625e-05,
#  'chi': 0.0010987913295375088,
#  'chicago': 9.989012086704625e-05,
#  'chief': 0.0004994506043352313,
#  'child': 9.989012086704625e-05,
#  'children': 0.000399560483468185,
#  'chile': 9.989012086704625e-05,
#  'chill': 9.989012086704625e-05,
#  'chillicoth': 9.989012086704625e-05,
#  'china': 0.0017980221756068325,
#  'chines': 0.0005993407252022775,
#  'ching': 0.0001997802417340925,
#  'chip': 9.989012086704625e-05,
#  'chizhov': 9.989012086704625e-05,
#  'chizov': 9.989012086704625e-05,
#  'choi': 9.989012086704625e-05,
#  'choic': 0.0001997802417340925,
#  'chok': 0.0001997802417340925,
#  'chon': 0.0001997802417340925,
#  'choos': 0.0001997802417340925,
#  'chose': 0.0001997802417340925,
#  'chri': 9.989012086704625e-05,
#  'christen': 9.989012086704625e-05,
#  'christian': 9.989012086704625e-05,
#  'christina': 9.989012086704625e-05,
#  'christma': 9.989012086704625e-05,
#  'christoph': 0.0006992308460693238,
#  'chrysanthemum': 9.989012086704625e-05,
#  'chu': 0.0001997802417340925,
#  'chunk': 9.989012086704625e-05,
#  'church': 9.989012086704625e-05,
#  'circl': 9.989012086704625e-05,
#  'circu': 9.989012086704625e-05,
#  'circuit': 9.989012086704625e-05,
#  'circul': 9.989012086704625e-05,
#  'circumst': 0.0001997802417340925,
#  'ciss': 9.989012086704625e-05,
#  'cite': 0.0001997802417340925,
#  'citi': 0.0014983518130056938,
#  'citizen': 0.0005993407252022775,
#  'civil': 0.00029967036260113877,
#  'civilian': 9.989012086704625e-05,
#  'claim': 9.989012086704625e-05,
#  'clair': 9.989012086704625e-05,
#  'clamor': 0.0001997802417340925,
#  'clash': 9.989012086704625e-05,
#  'class': 9.989012086704625e-05,
#  'classic': 9.989012086704625e-05,
#  'classifi': 0.00029967036260113877,
#  'classmat': 0.0001997802417340925,
#  'clean': 0.0001997802417340925,
#  'clear': 0.00029967036260113877,
#  'clearer': 9.989012086704625e-05,
#  'clearli': 0.00029967036260113877,
#  'clemenc': 9.989012086704625e-05,
#  'clergi': 9.989012086704625e-05,
#  'clerk': 9.989012086704625e-05,
#  'clever': 9.989012086704625e-05,
#  'click': 9.989012086704625e-05,
#  'client': 9.989012086704625e-05,
#  'clifford': 9.989012086704625e-05,
#  'clijster': 9.989012086704625e-05,
#  'climat': 9.989012086704625e-05,
#  'climatecontrol': 9.989012086704625e-05,
#  'climax': 0.0001997802417340925,
#  'climb': 9.989012086704625e-05,
#  'clinch': 9.989012086704625e-05,
#  'clinic': 9.989012086704625e-05,
#  'clinton': 0.011886924383178503,
#  'clod': 9.989012086704625e-05,
#  'closabl': 9.989012086704625e-05,
#  'close': 0.0006992308460693238,
#  'closeddoor': 9.989012086704625e-05,
#  'closer': 9.989012086704625e-05,
#  'closest': 9.989012086704625e-05,
#  'closhg': 9.989012086704625e-05,
#  'closur': 0.00029967036260113877,
#  'cloth': 0.00029967036260113877,
#  'cloud': 9.989012086704625e-05,
#  'club': 0.0001997802417340925,
#  'clue': 0.0004994506043352313,
#  'cmc': 0.0001997802417340925,
#  'cmdr': 9.989012086704625e-05,
#  'cnn': 9.989012086704625e-05,
#  'coach': 9.989012086704625e-05,
#  'coal': 9.989012086704625e-05,
#  'coalit': 9.989012086704625e-05,
#  'coalmin': 9.989012086704625e-05,
#  'coast': 0.00029967036260113877,
#  'coastal': 9.989012086704625e-05,
#  'coat': 9.989012086704625e-05,
#  'coca': 9.989012086704625e-05,
#  'cocain': 9.989012086704625e-05,
#  'cocoa': 9.989012086704625e-05,
#  'cocodi': 9.989012086704625e-05,
#  'code': 9.989012086704625e-05,
#  'codi': 0.000399560483468185,
#  'coffe': 9.989012086704625e-05,
#  'cohen': 9.989012086704625e-05,
#  'cold': 9.989012086704625e-05,
#  'cole': 9.989012086704625e-05,
#  'coler': 9.989012086704625e-05,
#  'colina': 9.989012086704625e-05,
#  'collaps': 9.989012086704625e-05,
#  'colleagu': 9.989012086704625e-05,
#  'collector': 9.989012086704625e-05,
#  'colleg': 0.00029967036260113877,
#  'coller': 9.989012086704625e-05,
#  'collid': 9.989012086704625e-05,
#  'collis': 9.989012086704625e-05,
#  'colo': 9.989012086704625e-05,
#  'colobora': 9.989012086704625e-05,
#  'colombian': 9.989012086704625e-05,
#  'coloni': 9.989012086704625e-05,
#  'colorado': 9.989012086704625e-05,
#  'columbia': 9.989012086704625e-05,
#  'column': 9.989012086704625e-05,
#  'columnist': 9.989012086704625e-05,
#  'comasagua': 9.989012086704625e-05,
#  'comb': 9.989012086704625e-05,
#  'combat': 0.0001997802417340925,
#  'combin': 9.989012086704625e-05,
#  'comeback': 9.989012086704625e-05,
#  'comfort': 9.989012086704625e-05,
#  'command': 0.0001997802417340925,
#  'commemor': 9.989012086704625e-05,
#  'comment': 9.989012086704625e-05,
#  'commerc': 0.0005993407252022775,
#  'commerci': 0.000399560483468185,
#  'commiss': 9.989012086704625e-05,
#  'commission': 9.989012086704625e-05,
#  'commit': 0.0006992308460693238,
#  'committe': 0.00029967036260113877,
#  'common': 9.989012086704625e-05,
#  'commonli': 9.989012086704625e-05,
#  'commun': 0.0001997802417340925,
#  'communiqu': 9.989012086704625e-05,
#  'communist': 0.002097692538207971,
#  'commut': 9.989012086704625e-05,
#  'compani': 0.0004994506043352313,
#  'compar': 9.989012086704625e-05,
#  'compart': 9.989012086704625e-05,
#  'compass': 0.0001997802417340925,
#  'compel': 9.989012086704625e-05,
#  'compens': 9.989012086704625e-05,
#  'compet': 9.989012086704625e-05,
#  'competit': 0.0001997802417340925,
#  'competitor': 9.989012086704625e-05,
#  'complain': 0.0001997802417340925,
#  'complaint': 9.989012086704625e-05,
#  'complet': 0.000399560483468185,
#  'complex': 0.00029967036260113877,
#  'compli': 9.989012086704625e-05,
#  'complic': 9.989012086704625e-05,
#  'compound': 9.989012086704625e-05,
#  'comprehens': 0.0001997802417340925,
#  'compromis': 9.989012086704625e-05,
#  'comput': 0.0001997802417340925,
#  'comrad': 9.989012086704625e-05,
#  'conceal': 9.989012086704625e-05,
#  'conced': 0.0001997802417340925,
#  'concentr': 9.989012086704625e-05,
#  'concern': 0.0001997802417340925,
#  'concert': 9.989012086704625e-05,
#  'conciliatori': 9.989012086704625e-05,
#  'conclud': 0.00029967036260113877,
#  'conclus': 9.989012086704625e-05,
#  'concret': 9.989012086704625e-05,
#  'condemn': 0.0001997802417340925,
#  'condit': 0.000399560483468185,
#  'condol': 9.989012086704625e-05,
#  'conduct': 9.989012086704625e-05,
#  'confer': 0.00029967036260113877,
#  'confid': 0.00029967036260113877,
#  'confin': 9.989012086704625e-05,
#  'confirm': 9.989012086704625e-05,
#  'conflict': 0.0001997802417340925,
#  'confound': 0.00029967036260113877,
#  'confront': 9.989012086704625e-05,
#  'confus': 9.989012086704625e-05,
#  'congratul': 9.989012086704625e-05,
#  'congress': 0.0005993407252022775,
#  'congression': 0.0001997802417340925,
#  'congressman': 9.989012086704625e-05,
#  'conjunct': 0.00029967036260113877,
#  'connal': 9.989012086704625e-05,
#  'connect': 9.989012086704625e-05,
#  'conqueror': 9.989012086704625e-05,
#  'consecut': 9.989012086704625e-05,
#  'consequ': 0.00029967036260113877,
#  'consid': 0.000399560483468185,
#  'consist': 9.989012086704625e-05,
#  'constant': 9.989012086704625e-05,
#  'constantinescu': 9.989012086704625e-05,
#  'constitu': 9.989012086704625e-05,
#  'constitut': 0.000399560483468185,
#  'construct': 0.0001997802417340925,
#  'consul': 0.00029967036260113877,
#  'consular': 0.0001997802417340925,
#  'consult': 9.989012086704625e-05,
#  'contact': 9.989012086704625e-05,
#  'contempt': 9.989012086704625e-05,
#  'contend': 9.989012086704625e-05,
#  'contest': 0.0001997802417340925,
#  'context': 9.989012086704625e-05,
#  'continu': 0.001198681450404555,
#  'contract': 9.989012086704625e-05,
#  'contradict': 9.989012086704625e-05,
#  'contrari': 0.0001997802417340925,
#  'contribut': 0.0001997802417340925,
#  'control': 9.989012086704625e-05,
#  'controversi': 9.989012086704625e-05,
#  'converg': 9.989012086704625e-05,
#  'convers': 9.989012086704625e-05,
#  'convict': 9.989012086704625e-05,
#  'convinc': 9.989012086704625e-05,
#  'convoy': 9.989012086704625e-05,
#  'cook': 9.989012086704625e-05,
#  'cool': 0.0001997802417340925,
#  'cooper': 0.0009989012086704626,
#  'coordin': 9.989012086704625e-05,
#  'cop': 9.989012086704625e-05,
#  'cope': 9.989012086704625e-05,
#  'coproduct': 9.989012086704625e-05,
#  'cordial': 0.0001997802417340925,
#  'cordillera': 9.989012086704625e-05,
#  'coretta': 9.989012086704625e-05,
#  'cori': 9.989012086704625e-05,
#  'corner': 9.989012086704625e-05,
#  'cornett': 9.989012086704625e-05,
#  'corp': 9.989012086704625e-05,
#  'corpor': 0.0001997802417340925,
#  'corps': 9.989012086704625e-05,
#  'correct': 9.989012086704625e-05,
#  'correspond': 9.989012086704625e-05,
#  'corros': 9.989012086704625e-05,
#  'corrupt': 0.0001997802417340925,
#  'cost': 0.0001997802417340925,
#  'costa': 9.989012086704625e-05,
#  'costli': 0.00029967036260113877,
#  'cotton': 9.989012086704625e-05,
#  'coulibali': 9.989012086704625e-05,
#  'council': 0.0004994506043352313,
#  'counselor': 9.989012086704625e-05,
#  'count': 0.00029967036260113877,
#  'counter': 9.989012086704625e-05,
#  'counterattack': 9.989012086704625e-05,
#  'counti': 9.989012086704625e-05,
#  'countless': 0.0001997802417340925,
#  'countri': 0.00399560483468185,
#  'countryman': 9.989012086704625e-05,
#  'countrymen': 9.989012086704625e-05,
#  'countrysid': 9.989012086704625e-05,
#  'coup': 9.989012086704625e-05,
#  'coupl': 9.989012086704625e-05,
#  'courag': 9.989012086704625e-05,
#  'courier': 9.989012086704625e-05,
#  ...}

# %% [markdown]
# <h4>Feature selection</h4>

# %%
#先建立一個算所有terms在所有文章中出現次數加總
#先前已計算個類別中字典裡所有字出現次數在eachCategorycnt_dict
#其中可能有反指標
wordSum_dict = {k: 0 for k in Allwords_dict}
for wd in wordSum_dict:
    for i in range(1,14):
        wordSum_dict[wd] += eachCategorycnt_dict[i][wd] #每個class出現次數加總即為總出現次數
        
chi_score_dict = {k: 0 for k in Allwords_dict} #另創一個紀錄chi-square value 
for wd in wordSum_dict:
    expected = wordSum_dict[wd] / 13
    score = 0
    for c in range(1,14):
        tmp = ((eachCategorycnt_dict[i][wd]-expected)**2)/expected
        score += tmp
    chi_score_dict[wd] = score
    
chi_score_dict = dict( sorted(chi_score_dict.items(), key=lambda x: x[1], reverse=True) ) #照大小排
#chi_score_dict
# Out:
# {'vietnam': 21988.30573248409,
#  'vietnames': 7631.999999999998,
#  'clinton': 7436.7903930131,
#  'visit': 6282.644736842103,
#  'hanoi': 5904.0,
#  'war': 3640.583333333335,
#  'trade': 2800.209302325582,
#  'presid': 2600.0,
#  'communist': 2574.727272727273,
#  'trip': 2358.8181818181815,
#  'busi': 2184.533333333334,
#  'unit': 2146.8571428571427,
#  'china': 2020.0500000000002,
#  'asia': 1880.0526315789477,
#  'saigon': 1727.9999999999998,
#  'american': 1565.3196721311476,
#  'econom': 1536.6399999999996,
#  'pow': 1439.9999999999995,
#  'powmia': 1439.9999999999995,
#  'minh': 1430.083333333333,
#  'remain': 1386.3936170212771,
#  'brunei': 1360.4090909090908,
#  'jone': 1312.2,
#  'agreement': 1300.0,
#  'servicemen': 1296.0000000000002,
#  'unifi': 1296.0000000000002,
#  'chi': 1287.3636363636365,
#  'relat': 1266.722222222222,
#  'relationship': 1188.6428571428576,
#  'global': 1160.3333333333333,
#  'paddi': 1152.0,
#  'refuge': 1144.8999999999999,
#  'rice': 1144.8999999999999,
#  'year': 1136.9661016949153,
#  'talk': 1053.0,
#  'south': 1028.1645569620252,
#  'peterson': 1002.777777777778,
#  'economi': 985.9599999999996,
#  'countri': 962.0642857142852,
#  'goe': 961.1428571428575,
#  'leader': 890.8604651162786,
#  'excav': 883.5999999999999,
#  'bunch': 863.9999999999999,
#  'cambodia': 863.9999999999999,
#  'christoph': 863.9999999999999,
#  'hawaii': 863.9999999999999,
#  'korean': 863.9999999999999,
#  'lao': 863.9999999999999,
#  'mia': 863.9999999999999,
#  'pastri': 863.9999999999999,
#  'repatri': 863.9999999999999,
#  'market': 861.1250000000002,
#  'ceremoni': 747.111111111111,
#  'reform': 747.111111111111,
#  'unaccount': 747.111111111111,
#  'nixon': 720.1428571428572,
#  'sidelin': 720.1428571428572,
#  'apolog': 719.9999999999998,
#  'benefit': 719.9999999999998,
#  'chapter': 719.9999999999998,
#  'chelsea': 719.9999999999998,
#  'commerc': 719.9999999999998,
#  'daejung': 719.9999999999998,
#  'evert': 719.9999999999998,
#  'farewel': 719.9999999999998,
#  'growth': 719.9999999999998,
#  'internet': 719.9999999999998,
#  'jiang': 719.9999999999998,
#  'mori': 719.9999999999998,
#  'societi': 719.9999999999998,
#  'spend': 719.9999999999998,
#  'yoshiro': 719.9999999999998,
#  'zemin': 719.9999999999998,
#  'north': 710.0357142857142,
#  'america': 703.1249999999999,
#  'berger': 648.4736842105264,
#  'pursu': 637.0,
#  'univers': 637.0,
#  'summit': 614.3225806451611,
#  'govern': 610.0416666666664,
#  'state': 591.8032786885246,
#  'action': 581.8181818181819,
#  'apec': 580.1666666666666,
#  'chines': 580.1666666666666,
#  'legal': 578.5714285714288,
#  'anthropologist': 576.0,
#  'bilater': 576.0,
#  'borneo': 576.0,
#  'embargo': 576.0,
#  'fighter': 576.0,
#  'formerli': 576.0,
#  'freedom': 576.0,
#  'minu': 576.0,
#  'nguyen': 576.0,
#  'sperl': 576.0,
#  'successor': 576.0,
#  'sultan': 576.0,
#  'symbol': 576.0,
#  'usback': 576.0,
#  'expand': 528.9999999999999,
#  'kim': 528.9999999999999,
#  'learn': 528.9999999999999,
#  'richard': 528.9999999999999,
#  'account': 504.0322580645162,
#  'pentagon': 497.782608695652,
#  'thursday': 486.1607142857145,
#  'accompani': 480.5714285714287,
#  'hillari': 480.5714285714287,
#  'invest': 480.5714285714287,
#  'program': 480.5714285714287,
#  'process': 480.49999999999994,
#  'cooper': 470.4499999999999,
#  'meet': 466.0425531914893,
#  'commit': 462.40000000000015,
#  'clue': 441.79999999999995,
#  'mysteri': 441.79999999999995,
#  'overse': 441.79999999999995,
#  'surrend': 441.79999999999995,
#  'threeday': 441.79999999999995,
#  'troop': 441.79999999999995,
#  'antiwar': 431.99999999999994,
#  'bear': 431.99999999999994,
#  'codi': 431.99999999999994,
#  'crater': 431.99999999999994,
#  'draft': 431.99999999999994,
#  'easier': 431.99999999999994,
#  'emigr': 431.99999999999994,
#  'empir': 431.99999999999994,
#  'flow': 431.99999999999994,
#  'fpt': 431.99999999999994,
#  'jet': 431.99999999999994,
#  'johnson': 431.99999999999994,
#  'lawrenc': 431.99999999999994,
#  'linger': 431.99999999999994,
#  'longstand': 431.99999999999994,
#  'lyndon': 431.99999999999994,
#  'opul': 431.99999999999994,
#  'proposit': 431.99999999999994,
#  'undertaken': 431.99999999999994,
#  'unfett': 431.99999999999994,
#  'warren': 431.99999999999994,
#  'wen': 431.99999999999994,
#  'worthsal': 431.99999999999994,
#  'wyo': 431.99999999999994,
#  'issu': 425.6333333333335,
#  'site': 425.6333333333335,
#  'asiapacif': 423.50000000000017,
#  'rest': 410.8888888888888,
#  'assur': 406.1250000000001,
#  'diplomat': 406.1250000000001,
#  'pacif': 385.0666666666668,
#  'nearli': 384.1739130434783,
#  'identif': 352.66666666666674,
#  'mostli': 352.66666666666674,
#  'rim': 352.66666666666674,
#  'korea': 348.44444444444446,
#  'outcom': 348.44444444444446,
#  'sinc': 344.01149425287343,
#  'normal': 328.0476190476191,
#  'doubt': 325.0,
#  'leav': 316.6808510638298,
#  'beach': 306.2500000000001,
#  'culmin': 306.2500000000001,
#  'joke': 306.2500000000001,
#  'kennedi': 306.2500000000001,
#  'occasion': 306.2500000000001,
#  'owe': 306.2500000000001,
#  'privat': 306.2500000000001,
#  'prosper': 306.2500000000001,
#  'reluct': 306.2500000000001,
#  'remark': 306.2500000000001,
#  'restrict': 306.2500000000001,
#  'revers': 306.2500000000001,
#  'rodham': 306.2500000000001,
#  'settl': 306.2500000000001,
#  'vigor': 306.2500000000001,
#  'effort': 303.6756756756756,
#  'resolv': 302.5,
#  'provid': 296.0555555555555,
#  'negoti': 292.57142857142867,
#  'posit': 292.57142857142867,
#  'annual': 289.2857142857144,
#  'anyon': 289.2857142857144,
#  'echo': 289.2857142857144,
#  'quarter': 289.2857142857144,
#  'speech': 289.2857142857144,
#  'studi': 289.2857142857144,
#  'agenda': 288.0,
#  'agon': 288.0,
#  'ann': 288.0,
#  'archaeolog': 288.0,
#  'bureaucraci': 288.0,
#  'bureaucrat': 288.0,
#  'captiv': 288.0,
#  'caucasian': 288.0,
#  'closur': 288.0,
#  'confound': 288.0,
#  'conjunct': 288.0,
#  'consul': 288.0,
#  'costli': 288.0,
#  'cussin': 288.0,
#  'dapist': 288.0,
#  'decadesold': 288.0,
#  'discrep': 288.0,
#  'dougla': 288.0,
#  'economist': 288.0,
#  'enddat': 288.0,
#  'flake': 288.0,
#  'footdeep': 288.0,
#  'framework': 288.0,
#  'fullest': 288.0,
#  'gene': 288.0,
#  'golf': 288.0,
#  'harvard': 288.0,
#  'hing': 288.0,
#  'hoe': 288.0,
#  'hollywood': 288.0,
#  'httpwwwdticmildpmo': 288.0,
#  'httpwwwdticmildpmopmseastatisticalreportshtm': 288.0,
#  'httpwwwusaorthembassyjtffahtm': 288.0,
#  'impass': 288.0,
#  'implement': 288.0,
#  'indochina': 288.0,
#  'integr': 288.0,
#  'itinerari': 288.0,
#  'journey': 288.0,
#  'lameduck': 288.0,
#  'liber': 288.0,
#  'lightheartedli': 288.0,
#  'longabandon': 288.0,
#  'mann': 288.0,
#  'mccain': 288.0,
#  'migrant': 288.0,
#  'moratorium': 288.0,
#  'motorcad': 288.0,
#  'mound': 288.0,
#  'movi': 288.0,
#  'nien': 288.0,
#  'odlon': 288.0,
#  'oilrich': 288.0,
#  'onequart': 288.0,
#  'onethird': 288.0,
#  'orang': 288.0,
#  'pact': 288.0,
#  'painstakingli': 288.0,
#  'persecut': 288.0,
#  'portion': 288.0,
#  'postelect': 288.0,
#  'prelud': 288.0,
#  'puzzl': 288.0,
#  'rancor': 288.0,
#  'rapproch': 288.0,
#  'reaffirm': 288.0,
#  'reeduc': 288.0,
#  'reiter': 288.0,
#  'remotest': 288.0,
#  'reopen': 288.0,
#  'repress': 288.0,
#  'returne': 288.0,
#  'roughli': 288.0,
#  'select': 288.0,
#  'siev': 288.0,
#  'sliver': 288.0,
#  'stephani': 288.0,
#  'stoni': 288.0,
#  'tariff': 288.0,
#  'turnaround': 288.0,
#  'unaccountedfor': 288.0,
#  'uncondit': 288.0,
#  'unresolv': 288.0,
#  'unshaken': 288.0,
#  'urgenc': 288.0,
#  'vietnameseamerican': 288.0,
#  'waiver': 288.0,
#  'warrel': 288.0,
#  'wartim': 288.0,
#  'withdraw': 288.0,
#  'withheld': 288.0,
#  'woodfram': 288.0,
#  'mani': 286.6764705882353,
#  'dont': 280.01449275362324,
#  'search': 273.7999999999999,
#  'daughter': 265.0909090909092,
#  'jan': 264.6,
#  'total': 252.05,
#  'dure': 242.64864864864853,
#  'centuri': 241.99999999999997,
#  'futur': 241.99999999999997,
#  'lift': 241.99999999999997,
#  'recount': 241.99999999999997,
#  'administr': 240.24999999999997,
#  'student': 234.08333333333326,
#  'putin': 233.7567567567567,
#  'ago': 233.6530612244897,
#  'divis': 231.20000000000007,
#  'easi': 231.20000000000007,
#  'increas': 231.20000000000007,
#  'religi': 231.20000000000007,
#  'continu': 222.75,
#  'foreign': 212.33333333333337,
#  'hotel': 208.0,
#  'human': 208.0,
#  'japanes': 208.0,
#  'pretti': 208.0,
#  'live': 206.28571428571436,
#  'address': 205.4444444444444,
#  'camp': 205.4444444444444,
#  'crowley': 205.4444444444444,
#  'flee': 205.4444444444444,
#  'reach': 192.11428571428567,
#  'citizen': 185.78571428571428,
#  'difficult': 185.78571428571428,
#  'asian': 181.49999999999991,
#  'broadcast': 181.49999999999991,
#  'encourag': 181.49999999999991,
#  'oversea': 181.49999999999991,
#  'case': 180.3265306122449,
#  'white': 178.3492063492063,
#  'achiev': 176.39999999999995,
#  'council': 176.39999999999995,
#  'deal': 176.39999999999995,
#  'enemi': 176.39999999999995,
#  'forum': 176.39999999999995,
#  'money': 176.39999999999995,
#  'sandi': 176.39999999999995,
#  'bag': 176.33333333333337,
#  'balanc': 176.33333333333337,
#  'bucket': 176.33333333333337,
#  'complex': 176.33333333333337,
#  'english': 176.33333333333337,
#  'exist': 176.33333333333337,
#  'fed': 176.33333333333337,
#  'fragment': 176.33333333333337,
#  'gordon': 176.33333333333337,
#  'greet': 176.33333333333337,
#  'highlight': 176.33333333333337,
#  'indefinit': 176.33333333333337,
#  'indonesia': 176.33333333333337,
#  'jam': 176.33333333333337,
#  'labor': 176.33333333333337,
#  'laboratori': 176.33333333333337,
#  'liberti': 176.33333333333337,
#  'malaysia': 176.33333333333337,
#  'meant': 176.33333333333337,
#  'proof': 176.33333333333337,
#  'regain': 176.33333333333337,
#  'smile': 176.33333333333337,
#  'suspens': 176.33333333333337,
#  'wash': 176.33333333333337,
#  'air': 174.23999999999998,
#  'immigr': 166.66666666666666,
#  'ha': 163.21502590673572,
#  'fujimori': 161.0,
#  'director': 154.71428571428572,
#  'nation': 153.9236641221374,
#  'democraci': 152.8181818181818,
#  'metal': 152.8181818181818,
#  'slow': 152.8181818181818,
#  'hard': 150.06249999999997,
#  'press': 150.06249999999997,
#  'age': 146.28571428571433,
#  'cautiou': 146.28571428571433,
#  'exampl': 146.28571428571433,
#  'paul': 146.28571428571433,
#  'acced': 144.0,
#  'admiringli': 144.0,
#  'advic': 144.0,
#  'airlin': 144.0,
#  'akin': 144.0,
#  'ambival': 144.0,
#  'amerasian': 144.0,
#  'animos': 144.0,
#  'arbitrari': 144.0,
#  'artifact': 144.0,
#  'asean': 144.0,
#  'auster': 144.0,
#  'backdrop': 144.0,
#  'battlefield': 144.0,
#  'bet': 144.0,
#  'billboard': 144.0,
#  'bind': 144.0,
#  'bowl': 144.0,
#  'brain': 144.0,
#  'breakthrough': 144.0,
#  'bride': 144.0,
#  'bright': 144.0,
#  'carat': 144.0,
#  'carefullypreserv': 144.0,
#  'carpet': 144.0,
#  'censor': 144.0,
#  'cha': 144.0,
#  'charl': 144.0,
#  'chef': 144.0,
#  'ching': 144.0,
#  'chok': 144.0,
#  'chon': 144.0,
#  'choos': 144.0,
#  'chose': 144.0,
#  'chu': 144.0,
#  'clamor': 144.0,
#  'classmat': 144.0,
#  'climax': 144.0,
#  'cmc': 144.0,
#  'combat': 144.0,
#  'compass': 144.0,
#  'comprehens': 144.0,
#  'contrari': 144.0,
#  'cool': 144.0,
#  'cordial': 144.0,
#  'corpor': 144.0,
#  'countless': 144.0,
#  'courtland': 144.0,
#  'coven': 144.0,
#  'curiou': 144.0,
#  'decentr': 144.0,
#  'deepen': 144.0,
#  'deeper': 144.0,
#  'defoli': 144.0,
#  'disastr': 144.0,
#  'dissent': 144.0,
#  'distant': 144.0,
#  'dni': 144.0,
#  'dominican': 144.0,
#  'dream': 144.0,
#  'drew': 144.0,
#  'drove': 144.0,
#  'duc': 144.0,
#  'duglon': 144.0,
#  'earnest': 144.0,
#  'ecommerc': 144.0,
#  'editori': 144.0,
#  'eighti': 144.0,
#  'electron': 144.0,
#  'enterpris': 144.0,
#  'entranc': 144.0,
#  'entrepreneurship': 144.0,
#  'environ': 144.0,
#  'era': 144.0,
#  'exam': 144.0,
#  'exodu': 144.0,
#  'extern': 144.0,
#  'extravag': 144.0,
#  'faster': 144.0,
#  'februari': 144.0,
#  'forcibl': 144.0,
#  'freer': 144.0,
#  'freewheel': 144.0,
#  'gallust': 144.0,
#  'glimps': 144.0,
#  'goh': 144.0,
#  'graciou': 144.0,
#  'granddaught': 144.0,
#  'gravit': 144.0,
#  'grew': 144.0,
#  'gullast': 144.0,
#  'haiphong': 144.0,
#  'halfdozen': 144.0,
#  'hardli': 144.0,
#  'hardlin': 144.0,
#  'hassl': 144.0,
#  'heal': 144.0,
#  'healthi': 144.0,
#  'height': 144.0,
#  'hell': 144.0,
#  'heritag': 144.0,
#  'hien': 144.0,
#  'hilton': 144.0,
#  'hitech': 144.0,
#  'hiv': 144.0,
#  'hue': 144.0,
#  'hurdl': 144.0,
#  'ideal': 144.0,
#  'immens': 144.0,
#  'imprison': 144.0,
#  'ineffici': 144.0,
#  'inlay': 144.0,
#  'intim': 144.0,
#  'isff': 144.0,
#  'isol': 144.0,
#  'italian': 144.0,
#  'jealous': 144.0,
#  'jerudong': 144.0,
#  'jointli': 144.0,
#  'kahn': 144.0,
#  'kha': 144.0,
#  'knowledg': 144.0,
#  'koreanmad': 144.0,
#  'lavish': 144.0,
#  'lazili': 144.0,
#  'leap': 144.0,
#  'limousin': 144.0,
#  'littleknown': 144.0,
#  'luong': 144.0,
#  'lush': 144.0,
#  'mainli': 144.0,
#  'manifest': 144.0,
#  'mansfield': 144.0,
#  'marbl': 144.0,
#  'marri': 144.0,
#  'math': 144.0,
#  'mathemat': 144.0,
#  'mausoleum': 144.0,
#  'midmorn': 144.0,
#  'midst': 144.0,
#  'migrat': 144.0,
#  'min': 144.0,
#  'ming': 144.0,
#  'monopol': 144.0,
#  'mostvisit': 144.0,
#  'necessarili': 144.0,
#  'necessit': 144.0,
#  'nervou': 144.0,
#  'ngan': 144.0,
#  'nice': 144.0,
#  'nowdemolish': 144.0,
#  'omit': 144.0,
#  'onetim': 144.0,
#  'ongo': 144.0,
#  'ordinari': 144.0,
#  'orlean': 144.0,
#  'outliv': 144.0,
#  'overdo': 144.0,
#  'overst': 144.0,
#  'overtim': 144.0,
#  'overtur': 144.0,
#  'paradox': 144.0,
#  'phieu': 144.0,
#  'philadelphia': 144.0,
#  'philippin': 144.0,
#  'plainli': 144.0,
#  'pleasur': 144.0,
#  'postwar': 144.0,
#  'powerhous': 144.0,
#  'prize': 144.0,
#  'prohibit': 144.0,
#  'propos': 144.0,
#  'provis': 144.0,
#  'pyongyang': 144.0,
#  'pyramid': 144.0,
#  'rariz': 144.0,
#  'ratifi': 144.0,
#  'reconcili': 144.0,
#  'rectifi': 144.0,
#  'reengag': 144.0,
#  'refugeeprocess': 144.0,
#  'resembl': 144.0,
#  'resettl': 144.0,
#  'reunif': 144.0,
#  'revolut': 144.0,
#  'rocki': 144.0,
#  'sake': 144.0,
#  'scant': 144.0,
#  'selfimpos': 144.0,
#  'senatorelect': 144.0,
#  'sentiment': 144.0,
#  'sevenyearlong': 144.0,
#  'shell': 144.0,
#  'sherman': 144.0,
#  'shine': 144.0,
#  'sibl': 144.0,
#  'signatur': 144.0,
#  'sixhour': 144.0,
#  'social': 144.0,
#  'softwar': 144.0,
#  'sorti': 144.0,
#  'sting': 144.0,
#  'stranglehold': 144.0,
#  'strateg': 144.0,
#  'subsidi': 144.0,
#  'substitut': 144.0,
#  'swift': 144.0,
#  'teem': 144.0,
#  'thereaft': 144.0,
#  'toietnam': 144.0,
#  'tong': 144.0,
#  'tran': 144.0,
#  'trang': 144.0,
#  'transform': 144.0,
#  'tu': 144.0,
#  'unavoid': 144.0,
#  'undisclos': 144.0,
#  'unexpectedli': 144.0,
#  'unintend': 144.0,
#  'unsettl': 144.0,
#  'uptod': 144.0,
#  'usrussia': 144.0,
#  'usrussian': 144.0,
#  'vestig': 144.0,
#  'warmer': 144.0,
#  'washingtonbas': 144.0,
#  'welleduc': 144.0,
#  'wellfound': 144.0,
#  'wendi': 144.0,
#  'wider': 144.0,
#  'windfal': 144.0,
#  'xuan': 144.0,
#  'youngster': 144.0,
#  'littl': 142.5454545454545,
#  'forc': 140.0142857142857,
#  'join': 135.52941176470594,
#  'milosev': 135.0,
#  'opposit': 135.0,
#  'abroad': 133.3333333333333,
#  'august': 133.3333333333333,
#  'document': 133.3333333333333,
#  'southeast': 133.3333333333333,
#  'hope': 128.44444444444449,
#  'carnahan': 123.99999999999997,
#  'kill': 121.0,
#  'consequ': 120.99999999999999,
#  'custom': 120.99999999999999,
#  'datelin': 120.99999999999999,
#  'disput': 120.99999999999999,
#  'edg': 120.99999999999999,
#  'establish': 120.99999999999999,
#  'excel': 120.99999999999999,
#  'facil': 120.99999999999999,
#  'fate': 120.99999999999999,
#  'forens': 120.99999999999999,
#  'greater': 120.99999999999999,
#  'grown': 120.99999999999999,
#  'impos': 120.99999999999999,
#  'island': 120.99999999999999,
#  'mention': 120.99999999999999,
#  'otherwis': 120.99999999999999,
#  'pay': 120.99999999999999,
#  'procedur': 120.99999999999999,
#  'reinforc': 120.99999999999999,
#  'relax': 120.99999999999999,
#  'sift': 120.99999999999999,
#  'signific': 120.99999999999999,
#  'sweep': 120.99999999999999,
#  'twist': 120.99999999999999,
#  'wield': 120.99999999999999,
#  'avoid': 120.12499999999999,
#  'french': 120.12499999999999,
#  'ill': 120.12499999999999,
#  'sens': 120.12499999999999,
#  'sometim': 120.12499999999999,
#  'noth': 117.0,
#  'school': 117.0,
#  'worri': 117.0,
#  'set': 114.63157894736838,
#  'develop': 112.35999999999996,
#  'georg': 111.36842105263155,
#  'juli': 111.36842105263155,
#  'polit': 109.92207792207792,
#  'open': 107.85507246376812,
#  'pope': 105.00000000000003,
#  'import': 104.0,
#  'speak': 103.14285714285718,
#  'young': 103.14285714285718,
#  'commerci': 100.0,
#  'court': 97.00000000000001,
#  'gener': 94.36734693877554,
#  'vladimir': 92.19047619047622,
#  'predict': 91.26666666666668,
#  'recoveri': 91.26666666666668,
#  'rumor': 91.26666666666668,
#  'hold': 89.28571428571429,
#  'convict': 88.99999999999997,
#  'conclud': 88.19999999999997,
#  'dramat': 88.19999999999997,
#  'expens': 88.19999999999997,
#  'focus': 88.19999999999997,
#  'frustrat': 88.19999999999997,
#  'hillsid': 88.19999999999997,
#  'histor': 88.19999999999997,
#  'invit': 88.19999999999997,
#  'midnight': 88.19999999999997,
#  'mud': 88.19999999999997,
#  'oppos': 88.19999999999997,
#  'pack': 88.19999999999997,
#  'plung': 88.19999999999997,
#  'reveal': 88.19999999999997,
#  'reward': 88.19999999999997,
#  'simpli': 88.19999999999997,
#  'spent': 88.19999999999997,
#  'stress': 88.19999999999997,
#  'tini': 88.19999999999997,
#  'true': 88.19999999999997,
#  'uncertainti': 88.19999999999997,
#  'especi': 84.09999999999997,
#  'sky': 84.09999999999997,
#  'onc': 84.04545454545453,
#  'wednesday': 84.0277777777778,
#  'governor': 84.00000000000001,
#  'began': 82.79310344827586,
#  'recov': 82.79310344827586,
#  'quak': 82.0,
#  'day': 81.05194805194805,
#  'florida': 80.99999999999997,
#  'nov': 80.99999999999997,
#  'sight': 80.99999999999997,
#  'outsid': 78.8108108108108,
#  'doe': 76.69565217391303,
#  'monday': 75.99999999999999,
#  'campaign': 74.99999999999999,
#  'earthquak': 74.0,
#  'fbi': 74.0,
#  'hous': 73.72800000000001,
#  'senat': 73.13043478260872,
#  'bone': 72.05882352941175,
#  'compani': 72.05882352941175,
#  'affair': 71.27272727272725,
#  'prime': 71.25806451612902,
#  'secretari': 71.25806451612902,
#  'stay': 71.25806451612902,
#  'team': 71.25806451612902,
#  'navi': 69.0,
#  'ivori': 68.00000000000001,
#  'salvador': 68.00000000000001,
#  'texa': 68.00000000000001,
#  'agre': 66.66666666666664,
#  'averag': 66.66666666666664,
#  'drop': 66.66666666666664,
#  'dug': 66.66666666666664,
#  'focu': 66.66666666666664,
#  'ignor': 66.66666666666664,
#  'intend': 66.66666666666664,
#  'leadership': 66.66666666666664,
#  'manufactur': 66.66666666666664,
#  'medina': 66.66666666666664,
#  'period': 66.66666666666664,
#  'session': 66.66666666666664,
#  'shape': 66.66666666666664,
#  'suspicion': 66.66666666666664,
#  'trim': 66.66666666666664,
#  'view': 66.66666666666664,
#  'welcom': 66.66666666666664,
#  'peru': 65.0,
#  'submarin': 63.999999999999986,
#  'resign': 63.0,
#  'san': 61.999999999999986,
#  'ambassador': 60.749999999999964,
#  'capt': 60.749999999999964,
#  'shop': 60.749999999999964,
#  'anxieti': 60.49999999999999,
#  'anywher': 60.49999999999999,
#  'basi': 60.49999999999999,
#  'bitterli': 60.49999999999999,
#  'book': 60.49999999999999,
#  'club': 60.49999999999999,
#  'congression': 60.49999999999999,
#  'consular': 60.49999999999999,
#  'detent': 60.49999999999999,
#  'disappoint': 60.49999999999999,
#  'dot': 60.49999999999999,
#  'drain': 60.49999999999999,
#  'element': 60.49999999999999,
#  'enjoy': 60.49999999999999,
#  'equal': 60.49999999999999,
#  'foundat': 60.49999999999999,
#  'giant': 60.49999999999999,
#  'gold': 60.49999999999999,
#  'grandson': 60.49999999999999,
#  'groundwork': 60.49999999999999,
#  'guest': 60.49999999999999,
#  'honest': 60.49999999999999,
#  'hostil': 60.49999999999999,
#  'infrastructur': 60.49999999999999,
#  'interim': 60.49999999999999,
#  'justifi': 60.49999999999999,
#  'lobbi': 60.49999999999999,
#  'merit': 60.49999999999999,
#  'oblig': 60.49999999999999,
#  'occas': 60.49999999999999,
#  'pari': 60.49999999999999,
#  'passag': 60.49999999999999,
#  'perfect': 60.49999999999999,
#  'perspect': 60.49999999999999,
#  'plagu': 60.49999999999999,
#  'preced': 60.49999999999999,
#  'precis': 60.49999999999999,
#  'print': 60.49999999999999,
#  'project': 60.49999999999999,
#  'prospect': 60.49999999999999,
#  'protestor': 60.49999999999999,
#  'prowestern': 60.49999999999999,
#  'rate': 60.49999999999999,
#  'ray': 60.49999999999999,
#  'recognit': 60.49999999999999,
#  'reformmind': 60.49999999999999,
#  'robinson': 60.49999999999999,
#  'scrap': 60.49999999999999,
#  'searcher': 60.49999999999999,
#  'socal': 60.49999999999999,
#  'soil': 60.49999999999999,
#  'somewher': 60.49999999999999,
#  'sped': 60.49999999999999,
#  'spous': 60.49999999999999,
#  'squar': 60.49999999999999,
#  'stall': 60.49999999999999,
#  'stern': 60.49999999999999,
#  'strengthen': 60.49999999999999,
#  'temporari': 60.49999999999999,
#  'toni': 60.49999999999999,
#  'torch': 60.49999999999999,
#  'transact': 60.49999999999999,
#  'translat': 60.49999999999999,
#  'unfair': 60.49999999999999,
#  'unfortun': 60.49999999999999,
#  'unschedul': 60.49999999999999,
#  'valu': 60.49999999999999,
#  'web': 60.49999999999999,
#  'ouattara': 59.99999999999998,
#  'work': 59.065789473684205,
#  'die': 59.000000000000014,
#  'express': 58.5,
#  'percent': 58.5,
#  'promis': 58.5,
#  'death': 57.00000000000002,
#  'men': 57.00000000000002,
#  'peltier': 57.00000000000002,
#  'thi': 56.88888888888888,
#  'explos': 55.000000000000014,
#  'sentenc': 54.0,
#  'ship': 54.0,
#  'law': 53.58139534883721,
#  'number': 53.48148148148145,
#  'build': 52.2236842105263,
#  'complet': 52.0,
#  'half': 52.0,
#  'independ': 52.0,
#  'senior': 52.0,
#  'station': 52.0,
#  'aircraft': 51.57142857142859,
#  'await': 51.57142857142859,
#  'built': 51.57142857142859,
#  'classifi': 51.57142857142859,
#  'debri': 51.57142857142859,
#  'duti': 51.57142857142859,
#  'eventu': 51.57142857142859,
#  'occur': 51.57142857142859,
#  'prevent': 51.57142857142859,
#  'specul': 51.57142857142859,
#  'train': 51.57142857142859,
#  'travel': 51.57142857142859,
#  'list': 51.2,
#  'injur': 50.999999999999986,
#  'polic': 50.22608695652174,
#  'area': 50.0,
#  'australian': 50.0,
#  'believ': 49.02816901408449,
#  'guei': 48.99999999999999,
#  'citi': 48.88990825688072,
#  'kostunica': 48.00000000000001,
#  'india': 47.38028169014083,
#  'escap': 46.99999999999999,
#  'montesino': 46.99999999999999,
#  'collaps': 46.000000000000014,
#  'hour': 46.000000000000014,
#  'david': 45.761904761904745,
#  'surviv': 45.761904761904745,
#  'voa': 45.761904761904745,
#  'pardon': 44.999999999999986,
#  'william': 44.999999999999986,
#  'yugoslavia': 44.999999999999986,
#  'group': 44.68965517241379,
#  'howev': 44.642857142857146,
#  'radio': 44.0,
#  'store': 44.0,
#  'coast': 43.68181818181818,
#  'cole': 42.99999999999999,
#  'control': 42.99999999999999,
#  'match': 42.99999999999999,
#  'kursk': 42.00000000000001,
#  'sampra': 42.00000000000001,
#  'tonight': 42.00000000000001,
#  'rule': 41.14285714285715,
#  'missouri': 41.0,
#  'serb': 41.0,
#  'trial': 41.0,
#  'cloth': 40.499999999999986,
#  'confer': 40.499999999999986,
#  'creat': 40.499999999999986,
#  'experi': 40.499999999999986,
#  'highli': 40.499999999999986,
#  'industri': 40.499999999999986,
#  'lay': 40.499999999999986,
#  'meanwhil': 40.499999999999986,
#  'resolut': 40.499999999999986,
#  'safe': 40.499999999999986,
#  'diver': 39.0,
#  'rescu': 39.0,
#  'safin': 39.0,
#  'thing': 39.0,
#  'servic': 38.7258064516129,
#  'gore': 38.52083333333332,
#  'embassi': 38.40000000000001,
#  'free': 38.40000000000001,
#  'interview': 38.40000000000001,
#  'hit': 37.99999999999999,
#  'belgrad': 37.0,
#  'victim': 36.0,
#  'tuesday': 35.864406779661,
#  'peopl': 35.302040816326524,
#  'agassi': 35.00000000000001,
#  'colina': 35.00000000000001,
#  'damag': 35.00000000000001,
#  'offici': 34.48066298342541,
#  'caus': 34.00000000000001,
#  'destroy': 34.00000000000001,
#  'junta': 34.00000000000001,
#  'seed': 34.00000000000001,
#  'serbia': 34.00000000000001,
#  'accomplish': 33.33333333333332,
#  'align': 33.33333333333332,
#  'barrier': 33.33333333333332,
#  'chair': 33.33333333333332,
#  'comput': 33.33333333333332,
#  'construct': 33.33333333333332,
#  'cost': 33.33333333333332,
#  'difficulti': 33.33333333333332,
#  'engag': 33.33333333333332,
#  'fascin': 33.33333333333332,
#  'flew': 33.33333333333332,
#  'gradual': 33.33333333333332,
#  'happi': 33.33333333333332,
#  'harder': 33.33333333333332,
#  'helicopt': 33.33333333333332,
#  'hire': 33.33333333333332,
#  'increasingli': 33.33333333333332,
#  'inevit': 33.33333333333332,
#  'infect': 33.33333333333332,
#  'invent': 33.33333333333332,
#  'nighttim': 33.33333333333332,
#  'notabl': 33.33333333333332,
#  'olymp': 33.33333333333332,
#  'panel': 33.33333333333332,
#  'path': 33.33333333333332,
#  'presenc': 33.33333333333332,
#  'reaction': 33.33333333333332,
#  'regul': 33.33333333333332,
#  'restaur': 33.33333333333332,
#  'river': 33.33333333333332,
#  'suppress': 33.33333333333332,
#  'technic': 33.33333333333332,
#  'thu': 33.33333333333332,
#  'undermin': 33.33333333333332,
#  'underway': 33.33333333333332,
#  'upscal': 33.33333333333332,
#  'vast': 33.33333333333332,
#  'wipe': 33.33333333333332,
#  'youth': 33.33333333333332,
#  'analyst': 33.06249999999999,
#  'care': 33.06249999999999,
#  'everi': 33.06249999999999,
#  'improv': 33.06249999999999,
#  'note': 33.06249999999999,
#  'appar': 33.00000000000001,
#  'base': 33.00000000000001,
#  'peac': 33.00000000000001,
#  'port': 33.00000000000001,
#  'suspect': 33.00000000000001,
#  'plane': 32.89473684210525,
#  'crash': 32.26666666666669,
#  'addit': 32.11111111111112,
#  'approv': 32.11111111111112,
#  'argu': 32.11111111111112,
#  'colleg': 32.11111111111112,
#  'inde': 32.11111111111112,
#  'personnel': 32.11111111111112,
#  'piec': 32.11111111111112,
#  'proceed': 32.11111111111112,
#  'attack': 32.07272727272728,
#  'respons': 31.999999999999993,
#  'tournament': 31.999999999999993,
#  'possibl': 31.37254901960784,
#  'return': 31.37254901960784,
#  'agent': 31.135135135135137,
#  'depart': 31.129629629629623,
#  'march': 30.999999999999993,
#  'terrorist': 30.999999999999993,
#  'violenc': 30.999999999999993,
#  'arriv': 30.857142857142843,
#  'guatemala': 29.99999999999999,
#  'robberi': 29.99999999999999,
#  'sele': 29.99999999999999,
#  'torpedo': 29.99999999999999,
#  'week': 29.950495049504948,
#  'becaus': 29.802816901408452,
#  'democrat': 29.388888888888896,
#  'moscow': 29.25,
#  'advis': 29.160000000000004,
#  'high': 29.160000000000004,
#  'prepar': 29.160000000000004,
#  'problem': 29.160000000000004,
#  'hand': 28.999999999999993,
#  'roger': 28.999999999999993,
#  'weapon': 28.999999999999993,
#  'children': 28.470588235294112,
#  'siewert': 28.470588235294112,
#  'major': 28.313725490196074,
#  'aden': 27.999999999999996,
#  'champion': 27.0,
#  'didnt': 27.0,
#  'figur': 27.0,
#  'hingi': 27.0,
#  'hospit': 27.0,
#  ...}

# %%
imp_feature = []
for key in chi_score_dict.keys():
    imp_feature.append(key)
imp_feature = imp_feature[545:1035]
len(imp_feature)
# Out:
# 490

# %%
test_id = np.arange(1,1096)
test_id = [x for x in test_id if x not in [int(item) for sublist in classDict[1:] for item in sublist]] #用來test的

# %%
def computeCat(docid): #return category
    with open(f'./data/{docid}.txt') as f:
        data=f.read()
        text = tokenize(data) 
        text = [x for x in text if x in imp_feature]
        maxC = 0
        maxValue = -2e200
        for i in range(1, 14):
            tmpValue = 0
            for word in text:
                tmpValue += math.log(params_dict[i][word])
            if tmpValue > maxValue:
                maxValue = tmpValue
                maxC = i
        return maxC

# %%
data = [] #用來最後輸出
for tid in test_id:
    tid_category = computeCat(tid)
    data.append([tid, tid_category])
df = pd.DataFrame(data, columns=['Id', 'Value'])   
df
# Out:
#        Id  Value
# 0      17      2
# 1      18      2
# 2      20      2
# 3      21      2
# 4      22      2
# ..    ...    ...
# 895  1091      6
# 896  1092      6
# 897  1093      6
# 898  1094      6
# 899  1095      4
#
# [900 rows x 2 columns]

# %%
df['Value'].value_counts()
# Out:
# 9     277
# 2     112
# 11     69
# 5      68
# 7      55
# 6      49
# 12     46
# 8      42
# 3      40
# 4      40
# 1      39
# 10     36
# 13     27
# Name: Value, dtype: int64

# %%
#df2 = pd.DataFrame(params_dict[13].items(), columns=['wd', 'val'])
#df2.sort_values(by='val')
import os   
df.to_csv('./outAns.csv', index=False)
